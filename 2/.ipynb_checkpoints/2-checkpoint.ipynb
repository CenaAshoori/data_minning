# %%
import pandas as pd
from sklearn import preprocessing, decomposition
import scipy.stats as stats

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
% matplotlib inline
matplotlib.style.use('fivethirtyeight')
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# # 1

# %%
social_network_ads = pd.read_csv('file/Social_Network_Ads.csv')
social_network_ads.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male  119            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
def my_zscores(values):
    mean = sum(values) / len(values)
    differences = [(value - mean)**2 for value in values]
    sum_of_differences = sum(differences)
    standard_deviation = (sum_of_differences / (len(values) - 1)) ** 0.5

    zscores = [(value - mean) / standard_deviation for value in values]
    return zscores

# %%
social_network_ads['MZ Age'] = my_zscores(social_network_ads['Age'])
social_network_ads['scipyZ Age'] = stats.zscore(social_network_ads['Age'])
social_network_ads['sklearnZ Age'] = preprocessing.StandardScaler().fit(social_network_ads[['Age']]).transform(social_network_ads[['Age']])

social_network_ads['MZ ESalary'] = my_zscores(social_network_ads['EstimatedSalary'])
social_network_ads['scipyZ ESalary'] = stats.zscore(social_network_ads['EstimatedSalary'])
social_network_ads['sklearnZ ESalary'] = preprocessing.StandardScaler().fit(social_network_ads[['EstimatedSalary']]).transform(social_network_ads[['EstimatedSalary']])
social_network_ads.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased    MZ Age  scipyZ Age  \
# 0  15624510    Male  119            19000          0  7.237746    7.246810
# 1  15810944    Male   35            20000          0 -0.259272   -0.259597
# 2  15668575  Female   26            43000          0 -1.062524   -1.063854
# 3  15603246  Female   27            57000          0 -0.973274   -0.974492
# 4  15804002    Male   19            76000          0 -1.687275   -1.689388
# 5  15728773    Male   27            58000          0 -0.973274   -0.974492
# 6  15598044  Female   27            84000          0 -0.973274   -0.974492
# 7  15694829  Female   32           150000          1 -0.527022   -0.527682
# 8  15600575    Male   25            33000          0 -1.151774   -1.153216
# 9  15727311  Female   35            65000          0 -0.259272   -0.259597
#
#    sklearnZ Age  MZ ESalary  scipyZ ESalary  sklearnZ ESalary
# 0      7.246810   -1.488183       -1.490046         -1.490046
# 1     -0.259597   -1.458854       -1.460681         -1.460681
# 2     -1.063854   -0.784307       -0.785290         -0.785290
# 3     -0.974492   -0.373714       -0.374182         -0.374182
# 4     -1.689388    0.183521        0.183751          0.183751
# 5     -0.974492   -0.344386       -0.344817         -0.344817
# 6     -0.974492    0.418146        0.418669          0.418669
# 7     -0.527682    2.353802        2.356750          2.356750
# 8     -1.153216   -1.077589       -1.078938         -1.078938
# 9     -0.259597   -0.139089       -0.139263         -0.139263

# %%
social_network_ads[['Age','EstimatedSalary']].apply(stats.zscore)
# Out:
#           Age  EstimatedSalary
# 0    7.246810        -1.490046
# 1   -0.259597        -1.460681
# 2   -1.063854        -0.785290
# 3   -0.974492        -0.374182
# 4   -1.689388         0.183751
# ..        ...              ...
# 395  0.723385        -0.844019
# 396  1.170195        -1.372587
# 397  1.080833        -1.460681
# 398 -0.170235        -1.078938
# 399  0.991471        -0.990844
#
# [400 rows x 2 columns]

# %%
minmax_scaler = preprocessing.MinMaxScaler(feature_range=(0,10))
minmax_scaler.fit(social_network_ads[['scipyZ Age','scipyZ ESalary']])
social_network_ads[['AgeMMS','ESalary MMS']] = minmax_scaler.transform(social_network_ads[['scipyZ Age','scipyZ ESalary']])
social_network_ads.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased    MZ Age  scipyZ Age  \
# 0  15624510    Male  119            19000          0  7.237746    7.246810
# 1  15810944    Male   35            20000          0 -0.259272   -0.259597
# 2  15668575  Female   26            43000          0 -1.062524   -1.063854
# 3  15603246  Female   27            57000          0 -0.973274   -0.974492
# 4  15804002    Male   19            76000          0 -1.687275   -1.689388
# 5  15728773    Male   27            58000          0 -0.973274   -0.974492
# 6  15598044  Female   27            84000          0 -0.973274   -0.974492
# 7  15694829  Female   32           150000          1 -0.527022   -0.527682
# 8  15600575    Male   25            33000          0 -1.151774   -1.153216
# 9  15727311  Female   35            65000          0 -0.259272   -0.259597
#
#    sklearnZ Age  MZ ESalary  scipyZ ESalary  sklearnZ ESalary     AgeMMS  \
# 0      7.246810   -1.488183       -1.490046         -1.490046  10.000000
# 1     -0.259597   -1.458854       -1.460681         -1.460681   1.683168
# 2     -1.063854   -0.784307       -0.785290         -0.785290   0.792079
# 3     -0.974492   -0.373714       -0.374182         -0.374182   0.891089
# 4     -1.689388    0.183521        0.183751          0.183751   0.099010
# 5     -0.974492   -0.344386       -0.344817         -0.344817   0.891089
# 6     -0.974492    0.418146        0.418669          0.418669   0.891089
# 7     -0.527682    2.353802        2.356750          2.356750   1.386139
# 8     -1.153216   -1.077589       -1.078938         -1.078938   0.693069
# 9     -0.259597   -0.139089       -0.139263         -0.139263   1.683168
#
#    ESalary MMS
# 0     0.296296
# 1     0.370370
# 2     2.074074
# 3     3.111111
# 4     4.518519
# 5     3.185185
# 6     5.111111
# 7    10.000000
# 8     1.333333
# 9     3.703704

# %%
X = social_network_ads[['Age','EstimatedSalary']]
transformer = preprocessing.RobustScaler().fit(X)
transformer
social_network_ads[['Age Robust','ESalary Robust']] = transformer.transform(X)
social_network_ads.tail(10)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased    MZ Age  scipyZ Age  \
# 390  15807837    Male   48            33000          1  0.900981    0.902109
# 391  15592570    Male   47            23000          1  0.811731    0.812747
# 392  15748589  Female   45            45000          1  0.633230    0.634023
# 393  15635893    Male   60            42000          1  1.971983    1.974453
# 394  15757632  Female   39            59000          0  0.097729    0.097851
# 395  15691863  Female   46            41000          1  0.722480    0.723385
# 396  15706071    Male   51            23000          1  1.168731    1.170195
# 397  15654296  Female   50            20000          1  1.079481    1.080833
# 398  15755018    Male   36            33000          0 -0.170022   -0.170235
# 399  15594041  Female   49            36000          1  0.990231    0.991471
#
#      sklearnZ Age  MZ ESalary  scipyZ ESalary  sklearnZ ESalary    AgeMMS  \
# 390      0.902109   -1.077589       -1.078938         -1.078938  2.970297
# 391      0.812747   -1.370870       -1.372587         -1.372587  2.871287
# 392      0.634023   -0.725651       -0.726560         -0.726560  2.673267
# 393      1.974453   -0.813636       -0.814655         -0.814655  4.158416
# 394      0.097851   -0.315057       -0.315452         -0.315452  2.079208
# 395      0.723385   -0.842964       -0.844019         -0.844019  2.772277
# 396      1.170195   -1.370870       -1.372587         -1.372587  3.267327
# 397      1.080833   -1.458854       -1.460681         -1.460681  3.168317
# 398     -0.170235   -1.077589       -1.078938         -1.078938  1.782178
# 399      0.991471   -0.989604       -0.990844         -0.990844  3.069307
#
#      ESalary MMS  Age Robust  ESalary Robust
# 390     1.333333      0.6875       -0.822222
# 391     0.592593      0.6250       -1.044444
# 392     2.222222      0.5000       -0.555556
# 393     2.000000      1.4375       -0.622222
# 394     3.259259      0.1250       -0.244444
# 395     1.925926      0.5625       -0.644444
# 396     0.592593      0.8750       -1.044444
# 397     0.370370      0.8125       -1.111111
# 398     1.333333     -0.0625       -0.822222
# 399     1.555556      0.7500       -0.755556

# %%
fig, (ax0,ax1, ax2, ax3) = plt.subplots(ncols = 4, figsize =(20, 5))
params = {"text.color" : "yellow",
          "xtick.color" : "crimson",
          "ytick.color" : "crimson"}
plt.rcParams.update(params)
ax0.set_title('Before Scaling')
sns.kdeplot(social_network_ads['Age'], ax = ax0, color ='r')
# sns.kdeplot(social_network_ads['EstimatedSalary'], ax = ax0, color ='b')

ax1.set_title('After StandardScaler')
sns.kdeplot(social_network_ads['scipyZ Age'], ax = ax1, color ='r')
# sns.kdeplot(social_network_ads['scipyZ ESalary'], ax = ax1, color ='b')

ax2.set_title('After Min-Max Scaling') 
sns.kdeplot(social_network_ads['AgeMMS'], ax = ax2, color ='r')
# sns.kdeplot(social_network_ads['ESalary MMS'], ax = ax2, color ='b')


ax3.set_title('After Robust Scaling')
sns.kdeplot(social_network_ads['Age Robust'], ax = ax3, color ='r')
# sns.kdeplot(social_network_ads['ESalary Robust'], ax = ax3, color ='b')

# XX = social_network_ads[['Age Robust']]
# minmax_scaler = preprocessing.MinMaxScaler(feature_range=(0,10)).fit(XX)
# social_network_ads[['Age MMS New']] = minmax_scaler.transform(XX)
# social_network_ads.head(10)

# ax4.set_title('After Min-Max Scaling on Robust Scaling')
# sns.kdeplot(social_network_ads['Age MMS New'], ax = ax4, color ='r')
# sns.kdeplot(social_network_ads['ESalary MMS New'], ax = ax4, color ='b')

plt.show()
# Out:
# KeyboardInterrupt

# %%
encoder = preprocessing.OneHotEncoder(handle_unknown='ignore')
encoder.fit(social_network_ads[['Gender']])

one_hot_cols = encoder.get_feature_names(['G'])
ont_hot_value = encoder.transform(social_network_ads[['Gender']]).toarray()

normal_col = encoder.feature_names_in_
normal_value = encoder.inverse_transform(ont_hot_value)

df = pd.DataFrame(columns=one_hot_cols,data=ont_hot_value)
social_network_ads = pd.concat([social_network_ads,df],axis=1)
social_network_ads = social_network_ads.drop(columns=normal_col)

social_network_ads.head(10)

# %%
df = pd.DataFrame(columns=normal_col,data=normal_value)
social_network_ads = pd.concat([social_network_ads,df],axis=1)

social_network_ads = social_network_ads.drop(columns=one_hot_cols)
social_network_ads.head(10)

# %% [markdown]
# # Question 2

# %%
mall_customers = pd.read_csv('file/Mall_Customers.csv')
mall_customers[['Age','Annual Income (k$)','Spending Score (1-100)']] = mall_customers[['Age','Annual Income (k$)','Spending Score (1-100)']].apply(stats.zscore)
mall_customers.head(10)

# %%
encoder = preprocessing.OneHotEncoder(handle_unknown='ignore')
encoder.fit(mall_customers[['Gender']])

one_hot_cols = encoder.get_feature_names(['G'])
ont_hot_value = encoder.transform(mall_customers[['Gender']]).toarray()

normal_col = encoder.feature_names_in_
normal_value = encoder.inverse_transform(ont_hot_value)

df = pd.DataFrame(columns=one_hot_cols,data=ont_hot_value)
mall_customers = pd.concat([mall_customers,df],axis=1)
mall_customers = mall_customers.drop(columns=normal_col)

mall_customers.head(10)

# %%
X = mall_customers[['G_Female', 'G_Male','Age','Annual Income (k$)','Spending Score (1-100)']]
pca = decomposition.PCA(n_components=5)
pca.fit(X)
pca.explained_variance_ratio_

# %%
X = mall_customers[['G_Female', 'G_Male','Age','Annual Income (k$)','Spending Score (1-100)']]
pca = decomposition.PCA(n_components=3)
pca.fit(X)
pca.explained_variance_ratio_

# %%
df = pd.DataFrame(columns=normal_col,data=normal_value)

mall_customers = pd.concat([mall_customers,df],axis=1)

mall_customers = mall_customers.drop(columns=one_hot_cols)
mall_customers.head(10)
