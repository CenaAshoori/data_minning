# %%
import pandas as pd
from sklearn import preprocessing, decomposition
import scipy.stats as stats 
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
% matplotlib inline
matplotlib.style.use('fivethirtyeight')
# Out:
# UsageError: Line magic function `%` not found.

# %%
# pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('people.csv')
display(df)
# Out:
#      قبل از تغییر دادن شیت کامنت این خونه رو بخونید.          Unnamed: 1  \
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                  ۱          کلیت رزومه
# 4                                                NaN             دانشگاه
# ...                                              ...                 ...
# 1174                                             NaN              مصاحبه
# 1175                                             NaN         وضعیت پذیرش
# 1176                                             NaN  تاریخ دریافت نتیجه
# 1177                                             NaN                فاند
# 1178                                             NaN         توضیح بیشتر
#
#       Unnamed: 2                                        رشته و مقطع  \
# 0            NaN                                    مقطع و سال ورود
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                        کارشناسی ۹۷
# 4            NaN                                               UIUC
# ...          ...                                                ...
# 1174         NaN                                     بعد از سابمیشن
# 1175         NaN                                     Final Decision
# 1176         NaN                                          mid March
# 1177         NaN             27k/year (tuition & insurance covered)
# 1178         NaN  اینکه من اول برای مستر اینجا اپلای کرده بودم.\...
#
#                                              Unnamed: 4  \
# 0                                                  رشته
# 1                                                   NaN
# 2                                                   NaN
# 3                                         علوم کامپیوتر
# 4                                                Purdue
# ...                                                 ...
# 1174                                     بعد از سابمیشن
# 1175                                                REJ
# 1176                                            mid Jan
# 1177                                                NaN
# 1178  با Mahdi Imani صحبت کردم. کارش ربطی به چیزی که...
#
#                                              Unnamed: 5  \
# 0                                            رشته‌ی دوم
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                            Washington
# ...                                                 ...
# 1174                                     بعد از سابمیشن
# 1175                                       ACC-Withdraw
# 1176                                           late Jan
# 1177                            21k/year (~ 6k tuition)
# 1178  من از Sharan آفری گرفتم. آدم خیلی خوبی بود. نه...
#
#                                              Unnamed: 6  \
# 0                                                ماینور
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                 UPenn
# ...                                                 ...
# 1174                                     بعد از سابمیشن
# 1175                                                REJ
# 1176                                          early Feb
# 1177                                                NaN
# 1178  ایمیلی میاد که shortlist شدید و تعداد زیادی me...
#
#                                              Unnamed: 7  \
# 0                                    گرایش (فقط ارشدها)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   UBC
# ...                                                 ...
# 1174                                     بعد از سابمیشن
# 1175                                                REJ
# 1176                                            mid Feb
# 1177                                                NaN
# 1178  با Mohamad Rsotami صحبت کردم و گفت بهش خبر بدم...
#
#                                              Unnamed: 8  \
# 0                                            فیلد اپلای
# 1                                                   NaN
# 2                                                   NaN
# 3      Programming Languages,\nFormal Methods,\nSystems
# 4                                                U of T
# ...                                                 ...
# 1174                                        بدون مصاحبه
# 1175                                       ACC-Withdraw
# 1176                                        early March
# 1177                                                NaN
# 1178  گفتند بیا اول مستر بخون. فاندی نداره و کمی پرو...
#
#                                                   نمرات  ...  \
# 0                                                  معدل  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3                                                 17.21  ...
# 4                                                  Utah  ...
# ...                                                 ...  ...
# 1174                                     بعد از سابمیشن  ...
# 1175                                                REJ  ...
# 1176                                       early April!  ...
# 1177                                                NaN  ...
# 1178  Christos ایمیل زد و گفت صحبت کنیم. ولی من آلرد...  ...
#
#                             Unnamed: 37           Unnamed: 38     Unnamed: 39  \
# 0     خدمات شریف ویزا و امثالهم / هزینه  تاریخ اکسپت کردن آفر  تاریخ صدور I20
# 1                                   NaN                   NaN             NaN
# 2                                   NaN                   NaN             NaN
# 3                                3 mill             March. 19       April. 13
# 4                                   NaN                   NaN             NaN
# ...                                 ...                   ...             ...
# 1174                                NaN                   NaN             NaN
# 1175                                NaN                   NaN             NaN
# 1176                                NaN                   NaN             NaN
# 1177                                NaN                   NaN             NaN
# 1178                                NaN                   NaN             NaN
#
#                        Unnamed: 40     Unnamed: 41         Unnamed: 42  \
# 0     تاریخ درخواستی برای اکسپدایت  نتیجه اکسپدایت  هزینه سفر به سفارت
# 1                              NaN             NaN                 NaN
# 2                              NaN             NaN                 NaN
# 3                              NaN             NaN                 NaN
# 4                              NaN             NaN                 NaN
# ...                            ...             ...                 ...
# 1174                           NaN             NaN                 NaN
# 1175                           NaN             NaN                 NaN
# 1176                           NaN             NaN                 NaN
# 1177                           NaN             NaN                 NaN
# 1178                           NaN             NaN                 NaN
#
#      Unnamed: 43                       Unnamed: 44      Unnamed: 45  \
# 0     وضعیت ویزا  شرایط ویزا (سینگل / مولتی / ...)  تاریخ صدور ویزا
# 1            NaN                               NaN              NaN
# 2            NaN                               NaN              NaN
# 3            NaN                               NaN              NaN
# 4            NaN                               NaN              NaN
# ...          ...                               ...              ...
# 1174         NaN                               NaN              NaN
# 1175         NaN                               NaN              NaN
# 1176         NaN                               NaN              NaN
# 1177         NaN                               NaN              NaN
# 1178         NaN                               NaN              NaN
#
#                                             Unnamed: 46
# 0                           سایر تجربیات مربوط به سفارت
# 1                                                   NaN
# 2                                                   NaN
# 3     سفارت خیلی لطف داشت و وقت اولیم رو کنسل کرد. د...
# 4                                                   NaN
# ...                                                 ...
# 1174                                                NaN
# 1175                                                NaN
# 1176                                                NaN
# 1177                                                NaN
# 1178                                                NaN
#
# [1179 rows x 47 columns]

# %%
stu_indexs = df.loc[(df.index+8)%11 == 0].index
stu_indexs[0]
new_df = pd.DataFrame(columns=df.columns)
new_df = new_df.append(df.loc[(df.index+8)%11 == 0: ])
# Out:
# C:\Users\Cena\AppData\Local\Temp/ipykernel_28956/992641992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append(df.loc[(df.index+8)%11 == 0])

# %%
new_df.head(10)
# Out:
#     قبل از تغییر دادن شیت کامنت این خونه رو بخونید.  Unnamed: 1 Unnamed: 2  \
# 3                                                 ۱  کلیت رزومه        NaN
# 14                                                ۲  کلیت رزومه        NaN
# 25                                                ۳  کلیت رزومه        NaN
# 36                                                ۴  کلیت رزومه        NaN
# 47                                                ۵  کلیت رزومه        NaN
# 58                                                ۶  کلیت رزومه        NaN
# 69                                                ۷  کلیت رزومه        NaN
# 80                                                ۸  کلیت رزومه        NaN
# 91                                                ۹  کلیت رزومه        NaN
# 102                                              ۱۰  کلیت رزومه        NaN
#
#      رشته و مقطع       Unnamed: 4 Unnamed: 5 Unnamed: 6       Unnamed: 7  \
# 3    کارشناسی ۹۷    علوم کامپیوتر        NaN        NaN              NaN
# 14   کارشناسی ۹۶  مهندسی کامپیوتر        NaN        NaN              NaN
# 25   کارشناسی ۹۷  مهندسی کامپیوتر        NaN        NaN              NaN
# 36   کارشناسی ۹۷  مهندسی کامپیوتر        NaN        NaN              NaN
# 47   کارشناسی ۹۷  مهندسی کامپیوتر        NaN        NaN              NaN
# 58   کارشناسی ۹۴  مهندسی کامپیوتر        NaN        NaN              NaN
# 69   کارشناسی ۹۷  مهندسی کامپیوتر        NaN        NaN              NaN
# 80   کارشناسی ۹۶    علوم کامپیوتر        NaN        NaN              NaN
# 91       ارشد ۹۸  مهندسی کامپیوتر      فیزیک        NaN  معماری کامپیوتر
# 102  کارشناسی ۹۶  مهندسی کامپیوتر        NaN        NaN              NaN
#
#                                             Unnamed: 8  نمرات  ...  \
# 3     Programming Languages,\nFormal Methods,\nSystems  17.21  ...
# 14             Computer Architecture,\nCloud Computing   18.1  ...
# 25                             ML Vision (Adversarial)  19.17  ...
# 36   Computer Graphics, AR/VR, Geometry Processing,...  19.18  ...
# 47   NLP, ML, Computational Linguistics, Computatio...  19.48  ...
# 58                                                 NLP   15.9  ...
# 69                         ML (Adversarial Robustness)   19.6  ...
# 80   Theory (Algorithms / Optimization) and with a ...  17.75  ...
# 91                                               ML/DL  17.51  ...
# 102                                              AI/ML  17.27  ...
#
#             Unnamed: 37 Unnamed: 38  \
# 3                3 mill   March. 19
# 14                  NaN         NaN
# 25   عابدی (یک و شیشصد)         NaN
# 36                  NaN         NaN
# 47                  NaN         NaN
# 58                  NaN         NaN
# 69   عابدی (یک و شیشصد)       Apr 5
# 80              نه هنوز       Apr 2
# 91                  NaN         NaN
# 102                 NaN         NaN
#
#                                            Unnamed: 39 Unnamed: 40  \
# 3                                            April. 13         NaN
# 14                                                 NaN         NaN
# 25                                                 NaN         NaN
# 36                                                 NaN         NaN
# 47                                                 NaN         NaN
# 58                                                 NaN         NaN
# 69                                              Mar 23      Mar 28
# 80   Asking for Admission Supplement: Apr 19\nI20 I...         NaN
# 91                                                 NaN         NaN
# 102                                                NaN         NaN
#
#     Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44 Unnamed: 45  \
# 3           NaN         NaN         NaN         NaN         NaN
# 14          NaN         NaN         NaN         NaN         NaN
# 25          NaN         NaN         NaN         NaN         NaN
# 36          NaN         NaN         NaN         NaN         NaN
# 47          NaN         NaN         NaN         NaN         NaN
# 58          NaN         NaN         NaN         NaN         NaN
# 69    Rejected!         NaN         NaN         NaN         NaN
# 80          NaN         NaN         NaN         NaN         NaN
# 91          NaN         NaN         NaN         NaN         NaN
# 102         NaN         NaN         NaN         NaN         NaN
#
#                                            Unnamed: 46
# 3    سفارت خیلی لطف داشت و وقت اولیم رو کنسل کرد. د...
# 14                                                 NaN
# 25                                                 NaN
# 36                                                 NaN
# 47                                                 NaN
# 58                                                 NaN
# 69                                                 NaN
# 80   ۱- من خیلی شانسی موفق شدم که وقت سفارتم رو ریس...
# 91                                                 NaN
# 102                                                NaN
#
# [10 rows x 47 columns]
